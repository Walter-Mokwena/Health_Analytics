# %% [markdown]
# <a href="https://colab.research.google.com/github/Walter-Mokwena/Health_Analytics/blob/main/tb_socioeconomic_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data = 'https://github.com/Walter-Mokwena/Health_Analytics/blob/main/da_tb_data_2024.csv?raw=true'

# %%
df = pd.read_csv(Data, sep=';', decimal=',', on_bad_lines='skip')

# %%
df.head()
# Out:
#                  District   2024  DS TB patients who were lost to follow up  \
# 0        !Kheis LM: NC084  11.50                                         15
# 1          A Nzo DM: DC44   7.10                                        187
# 2    Abaqulusi LM: KZN263   0.86                                          6
# 3  Alfred Duma LM: KZN238   5.50                                         47
# 4     Amahlathi LM: EC124   6.50                                         43
#
#    All DS TB patients in cohort
# 0                           131
# 1                          2644
# 2                           699
# 3                           849
# 4                           663

# %%
f'num of rows: {df.shape[0]}   number of colums: {df.shape[1]}'
# Out:
# 'num of rows: 310   number of colums: 8'

# %%
df.head()
# Out:
#                  District   2024
# 0        !Kheis LM: NC084  11.50
# 1          A Nzo DM: DC44   7.10
# 2    Abaqulusi LM: KZN263   0.86
# 3  Alfred Duma LM: KZN238   5.50
# 4     Amahlathi LM: EC124   6.50
